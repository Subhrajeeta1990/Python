# %% [markdown]
# # Introduction to Python
#
#
# - The cat is black.
# - The dog is friendly.
# ![Centurion%20LOgo.png](attachment:Centurion%20LOgo.png)

# %%
ord("@")
# Out:
# 64

# %%
S="10"
type(S)
# Out:
# str

# %%
c= 3+5j
type(c)
# Out:
# complex

# %%
a=True
type(a)
# Out:
# bool

# %%
aman123= 555

# %%
aman123
# Out:
# 555

# %%
123aman=555
# Out:
#   File "<ipython-input-16-95379d9ee529>", line 1
#     123aman=555
#        ^
# SyntaxError: invalid syntax

# %%
Am123an=555

# %%
Am123an
# Out:
# 555

# %%
@aman=555
# Out:
#   File "<ipython-input-19-e810196da8b0>", line 1
#     @aman=555
#          ^
# SyntaxError: invalid syntax

# %%
Aman@=555
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d4418452ec5b> in <module>
# ----> 1 Aman@=555
#
# NameError: name 'Aman' is not defined

# %%
Am@an=555
# Out:
#   File "<ipython-input-21-a93d20dc6c86>", line 1
#     Am@an=555
#     ^
# SyntaxError: cannot assign to operator

# %%
_aman=555

# %%
_aman
# Out:
# 555

# %%
Am_an=555

# %%
Am_an
# Out:
# 555

# %%
aman_=555

# %%
aman_
# Out:
# 555

# %%
_123=555

# %%
True=10
# Out:
#   File "<ipython-input-29-f9c1faaf4ad0>", line 1
#     True=10
#     ^
# SyntaxError: cannot assign to True

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a=10
float(a)
# Out:
# 10.0

# %%
a
# Out:
# 10

# %%
a=10
a=float(a)

# %%
a
# Out:
# 10.0

# %%
a=str(a)

# %%
a
# Out:
# '10.0'

# %%
a=int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-30ff206e9968> in <module>
# ----> 1 a=int(a)
#
# ValueError: invalid literal for int() with base 10: '10.0'

# %%
a=int(float(a))

# %%
a
# Out:
# 10

# %%
# we need to carry out conversion in this way:
first str,int,float,int,str and float

# %%
s=123
s=float(str(int(float(int(str(s))))))

# %%
s
# Out:
# 123.0

# %%
a=10
print(a)
# Out:
# 10
